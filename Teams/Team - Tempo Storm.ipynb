# %% [markdown]
# # Tempo Storm

# %% [markdown]
# ## 1. Team Members

# %% [markdown]
# * reynad27
# * GaaraBestShaman
# * ratsmah
# * Reckful
# * Hyp3d
# * eloise_ailv
# * justsaiyanHS

# %%
cd C:\tmp
# Out:
# C:\tmp

# %%
import pandas as pd
import datetime
import time
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import create_list
# %matplotlib inline

# %% [markdown]
# ## 2. Creating Dataframe

# %%
tempostorm_df = pd.read_csv("tempostorm.csv", header=0, 
                 names=['name', 'followers', 'current_viewers', 'days', 'hours', 'minutes', 'current_date']).reset_index(drop=True)
tempostorm_df['current_date'] = pd.to_datetime(tempostorm_df['current_date'])

# %%
datetime_df = create_list.make_empty_dataframe(tempostorm_df)

# %%
tempostorm_df_agg = tempostorm_df.groupby('current_date').agg({'current_viewers': 'sum', 'followers': 'sum'})
tempostorm_df_agg.reset_index(inplace=True)

# %%
temp_df = pd.merge(datetime_df, tempostorm_df_agg, how='outer', left_index=True, right_on='current_date')
temp_df.reset_index(inplace=True)

# %%
temp_df['current_viewers'].fillna(0, inplace=True)
temp_df['week'] = pd.DatetimeIndex(temp_df['current_date']).week
temp_df['weekday'] = pd.DatetimeIndex(temp_df['current_date']).weekday

# %%
temp_df.drop(['index', 'A'], 1, inplace=True)
temp_df.set_index('current_date', inplace=True)
temp_df.index.name = None

# %% [markdown]
# ## 3. Team Specifics

# %% [markdown]
# ### Average Viewers Vs Time

# %%
fig2, axes= plt.subplots(nrows=1, ncols=4)
temp_df[(temp_df['week']==22) | (temp_df['week']==23)].plot(y='current_viewers', ax=axes[0], title='Week 1', figsize=(16,8), sharey=True, ylim=(0,35000))
temp_df[temp_df['week']==24].plot(y='current_viewers', ax=axes[1], title='Week 2')
temp_df[temp_df['week']==25].plot(y='current_viewers', ax=axes[2], title='Week 3', figsize=(20,4))
temp_df[(temp_df['week']==26) | (temp_df['week']==27)].plot(y='current_viewers', ax=axes[3], title='Week 4')

# %% [markdown]
# ### Histogram Of Hours Streamed For Each Individual

# %%
tempostorm_df.hist("hours", by='name', bins=24, sharex=True, sharey=True, figsize=(16,6), range=(0,23))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0845B990>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109B0FB0>]], dtype=object)

# %% [markdown]
# ### Histogram Of Days Streamed For Each Individual

# %%
tempostorm_df['weekday'] = pd.DatetimeIndex(tempostorm_df['current_date']).weekday

# %%
tempostorm_df.hist('weekday', by='name', bins=7, sharey=True, sharex=True, figsize=(16,6), range=(0,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10AC7AB0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110D5E30>]], dtype=object)
